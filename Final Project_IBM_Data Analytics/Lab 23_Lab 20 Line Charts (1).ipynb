# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Line Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on using line charts to analyze trends over time and across different categories in a dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Track trends in compensation across age groups and specific age ranges.
#
# - Analyze job satisfaction trends based on experience level.
#
# - Explore and interpret line charts to identify patterns and trends.

# %% [markdown]
# ## Setup: Working with the Database
# **Install the needed libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 83.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 124.8 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 101.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 93.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 46.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 93.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %% [markdown]
# #### Step 1: Download the dataset

# %%
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Out:
# --2026-02-25 21:04:58--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  48.3MB/s    in 3.2s
#
# 2026-02-25 21:05:01 (48.2 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]

# %% [markdown]
# #### Step 2: Import necessary libraries and load the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the data

# %%
df = pd.read_csv("survey-data.csv")

# %% [markdown]
# #### Display the first few rows to understand the structure of the data

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Trends in Compensation Over Age Groups

# %% [markdown]
# ##### 1. Line Chart of Median `ConvertedCompYearly` by Age Group

# %% [markdown]
# - Track how the median yearly compensation (ConvertedCompYearly) changes across different age groups.
#
# - Use a line chart to visualize these trends.

# %%
## Write your code here
import numpy as np

def age_to_midpoint(age_str):
    s = str(age_str).strip()
    if s.lower().startswith("under"):
        return 16.0
    if "or older" in s.lower():
        try:
            n = float(s.split()[0])
            return n + 2.5
        except:
            return np.nan
    if "-" in s:
        try:
            left = float(s.split("-")[0])
            right = float(s.split("-")[1].split()[0])
            return (left + right) / 2
        except:
            return np.nan
    try:
        return float(s)
    except:
        return np.nan

d = df[["Age", "ConvertedCompYearly"]].dropna().copy()
d["ConvertedCompYearly"] = pd.to_numeric(d["ConvertedCompYearly"], errors="coerce")
d = d.dropna(subset=["ConvertedCompYearly"])
d = d[d["ConvertedCompYearly"] > 0]

age_map = (
    d[["Age"]].drop_duplicates()
    .assign(Age_mid=lambda x: x["Age"].apply(age_to_midpoint))
    .dropna()
)
d = d.merge(age_map, on="Age", how="inner")

median_by_age = (
    d.groupby(["Age", "Age_mid"])["ConvertedCompYearly"]
    .median()
    .reset_index()
    .sort_values("Age_mid")
)

plt.figure(figsize=(12, 6))
plt.plot(median_by_age["Age"], median_by_age["ConvertedCompYearly"], marker="o")
plt.title("Median ConvertedCompYearly by Age Group")
plt.xlabel("Age group")
plt.ylabel("Median ConvertedCompYearly")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2. Line Chart of Median `ConvertedCompYearly` for Ages 25 to 45

# %% [markdown]
# For a closer look, plot a line chart focusing on the median compensation for respondents between ages 25 and 45.

# %%
## Write your code here
import numpy as np

d = df[["Age", "ConvertedCompYearly"]].dropna().copy()
d["ConvertedCompYearly"] = pd.to_numeric(d["ConvertedCompYearly"], errors="coerce")
d = d.dropna(subset=["ConvertedCompYearly"])
d = d[d["ConvertedCompYearly"] > 0]

d["Age_mid"] = d["Age"].apply(age_to_midpoint)
d = d.dropna(subset=["Age_mid"])
d = d[(d["Age_mid"] >= 25) & (d["Age_mid"] <= 45)]

median_by_age = (
    d.groupby("Age_mid")["ConvertedCompYearly"]
    .median()
    .sort_index()
)

plt.figure(figsize=(10, 6))
plt.plot(median_by_age.index, median_by_age.values, marker="o")
plt.title("Median ConvertedCompYearly for Ages 25–45 (by midpoint age)")
plt.xlabel("Age (midpoint)")
plt.ylabel("Median ConvertedCompYearly")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 2: Trends in Job Satisfaction by Experience Level

# %% [markdown]
# ##### 1. Line Chart of Job Satisfaction (`JobSatPoints_6`) by Experience Level

# %% [markdown]
# - Use a column that approximates experience level to analyze how job satisfaction changes with experience.
#
# - If needed, substitute an available experience-related column for `Experience`.

# %%
## Write your code here
d = df[["YearsCodePro", "JobSatPoints_6"]].dropna().copy()

y = (
    d["YearsCodePro"]
    .astype(str)
    .str.strip()
    .replace({"Less than 1 year": "0.5", "More than 50 years": "51"})
)
d["YearsCodePro_num"] = pd.to_numeric(y, errors="coerce")
d["JobSatPoints_6"] = pd.to_numeric(d["JobSatPoints_6"], errors="coerce")
d = d.dropna(subset=["YearsCodePro_num", "JobSatPoints_6"])

# Experience bins
bins = [0, 5, 10, 20, 60]
labels = ["0–5", "6–10", "11–20", "21+"]

d["ExpGroup"] = pd.cut(d["YearsCodePro_num"], bins=bins, labels=labels, include_lowest=True)

avg_js = d.groupby("ExpGroup")["JobSatPoints_6"].mean().reindex(labels)

plt.figure(figsize=(10, 6))
plt.plot(avg_js.index.astype(str), avg_js.values, marker="o")
plt.title("Average JobSatPoints_6 by Experience Level (YearsCodePro)")
plt.xlabel("Experience group (years)")
plt.ylabel("Average JobSatPoints_6")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Trends in Job Satisfaction and Compensation by Experience

# %% [markdown]
# ##### 1.Line Chart of Median ConvertedCompYearly Over Experience Level
#
# - This line chart will track how median compensation (`ConvertedCompYearly`) changes with increasing experience.
#
# - Use a column such as `WorkExp` or another relevant experience-related column.

# %%
## Write your code here
d = df[["YearsCodePro", "ConvertedCompYearly"]].dropna().copy()

y = (
    d["YearsCodePro"]
    .astype(str)
    .str.strip()
    .replace({"Less than 1 year": "0.5", "More than 50 years": "51"})
)
d["YearsCodePro_num"] = pd.to_numeric(y, errors="coerce")
d["ConvertedCompYearly"] = pd.to_numeric(d["ConvertedCompYearly"], errors="coerce")
d = d.dropna(subset=["YearsCodePro_num", "ConvertedCompYearly"])
d = d[d["ConvertedCompYearly"] > 0]

bins = [0, 5, 10, 15, 20, 25, 30, 40, 60]
labels = ["0–5", "6–10", "11–15", "16–20", "21–25", "26–30", "31–40", "41+"]

d["ExpBin"] = pd.cut(d["YearsCodePro_num"], bins=bins, labels=labels, include_lowest=True)

med_comp = d.groupby("ExpBin")["ConvertedCompYearly"].median().reindex(labels)

plt.figure(figsize=(11, 6))
plt.plot(med_comp.index.astype(str), med_comp.values, marker="o")
plt.title("Median ConvertedCompYearly by Experience Level (YearsCodePro)")
plt.xlabel("Experience bin (years)")
plt.ylabel("Median ConvertedCompYearly")
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2.Line Chart of Job Satisfaction (`JobSatPoints_6`) Across Experience Levels
#
# - Create a line chart to explore trends in job satisfaction (`JobSatPoints_6`) based on experience level.
#
# - This chart will provide insight into how satisfaction correlates with experience over time

# %%
## Write your code here
d = df[["YearsCodePro", "JobSatPoints_6"]].dropna().copy()

y = (
    d["YearsCodePro"]
    .astype(str)
    .str.strip()
    .replace({"Less than 1 year": "0.5", "More than 50 years": "51"})
)
d["YearsCodePro_num"] = pd.to_numeric(y, errors="coerce")
d["JobSatPoints_6"] = pd.to_numeric(d["JobSatPoints_6"], errors="coerce")
d = d.dropna(subset=["YearsCodePro_num", "JobSatPoints_6"])

bins = [0, 5, 10, 15, 20, 25, 30, 40, 60]
labels = ["0–5", "6–10", "11–15", "16–20", "21–25", "26–30", "31–40", "41+"]

d["ExpBin"] = pd.cut(d["YearsCodePro_num"], bins=bins, labels=labels, include_lowest=True)

avg_js = d.groupby("ExpBin")["JobSatPoints_6"].mean().reindex(labels)

plt.figure(figsize=(11, 6))
plt.plot(avg_js.index.astype(str), avg_js.values, marker="o")
plt.title("Average JobSatPoints_6 by Experience Level (YearsCodePro)")
plt.xlabel("Experience bin (years)")
plt.ylabel("Average JobSatPoints_6")
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Final Step: Review

# %% [markdown]
# In this lab, you focused on analyzing trends in compensation and job satisfaction, specifically exploring how these metrics change with age and experience levels using line charts.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you explored essential data visualization techniques with a focus on analyzing trends using line charts. You learned to:
#
# - Visualize the distribution of compensation across age groups to understand salary trends.
#
# - Track changes in median compensation over various experience levels, identifying how earnings progress with experience.
#
# - Examine trends in job satisfaction by experience, revealing how satisfaction varies throughout a developer's career.
#
# These analyses allow for a deeper understanding of how factors like age and experience influence job satisfaction and compensation. By using line charts, you gained insights into continuous data patterns, which are invaluable for interpreting professional trends in the developer community.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-10-16|1.1|Madhusudhan Moole|Updated lab|
# |2024-10-15|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
